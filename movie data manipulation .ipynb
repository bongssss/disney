# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
imdb= pd.read_csv("disney_movies.csv", index_col = [0])#read data set and start column index from 0

# %%
imdb.head()
#return top 10 entries in dataset
# Out:
#                              title       Production company        Country  \
# 0          Academy Award Review of  Walt Disney Productions  United States
# 1  Snow White and the Seven Dwarfs  Walt Disney Productions  United States
# 2                        Pinocchio  Walt Disney Productions  United States
# 3                         Fantasia  Walt Disney Productions  United States
# 4             The Reluctant Dragon  Walt Disney Productions  United States
#
#   Language  Running time     Budget    Box office Release date  imdb  \
# 0  English          41.0        NaN  4.547200e+01   1937-05-19   7.2
# 1  English          83.0  1490000.0  4.180000e+08   1937-12-21   7.6
# 2  English          88.0  2600000.0  1.640000e+08   1940-02-07   7.4
# 3  English         126.0  2280000.0  8.330000e+07   1940-11-13   7.7
# 4  English          74.0   600000.0  9.600000e+05   1941-06-20   6.9
#
#    metascore rotten_tomatoes  \
# 0        NaN             NaN
# 1       95.0             NaN
# ...

# %%
imdb.shape
# number of rows and columns in dataset
# Out:
# (444, 20)

# %%
imdb.describe () # describes the data in a dataframe
# Out:
#        Running time        Budget    Box office        imdb   metascore
# count    430.000000  2.780000e+02  3.580000e+02  424.000000  293.000000
# mean      98.076744  5.638595e+07  1.702417e+08    6.566274   61.860068
# std       21.418924  7.111427e+07  2.803541e+08    0.965122   16.756236
# min       40.000000  4.400000e+00  7.700000e+00    1.500000   18.000000
# 25%       86.250000  6.000000e+06  1.042500e+07    6.100000   49.000000
# 50%       96.000000  2.500000e+07  4.470000e+07    6.600000   61.000000
# 75%      107.000000  8.500000e+07  1.867750e+08    7.200000   74.000000
# max      306.000000  4.106000e+08  1.657000e+09    8.600000   99.000000

# %%
imdb.metascore.describe() #describes the mestascore column
# Out:
# count    293.000000
# mean      61.860068
# std       16.756236
# min       18.000000
# 25%       49.000000
# 50%       61.000000
# 75%       74.000000
# max       99.000000
# Name: metascore, dtype: float64

# %%
 imdb.duplicated()
# check for duplicate data entries
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 439    False
# 440    False
# 441    False
# 442    False
# 443    False
# Length: 444, dtype: bool

# %%
imdb.isnull() # check for null entries/empty columns
# Out:
#      title  Production company  Country  Language  Running time  Budget  \
# 0    False               False    False     False         False    True
# 1    False               False    False     False         False   False
# 2    False               False    False     False         False   False
# 3    False               False    False     False         False   False
# 4    False               False    False     False         False   False
# ..     ...                 ...      ...       ...           ...     ...
# 439  False               False    False     False          True    True
# 440  False               False    False     False          True    True
# 441  False               False    False     False          True    True
# 442  False               False    False     False          True    True
# 443  False               False    False     False         False   False
#
#      Box office  Release date   imdb  metascore  rotten_tomatoes  Directed by  \
# ...

# %%
imdb.dropna(axis=0, how="any", ).shape # drop misssing values
# Out:
# (53, 20)

# %%
imdb.dropna(axis=0, how="any", inplace= True )

# %%
imdb.isnull() # check for null entries again
# Out:
#      title  Production company  Country  Language  Running time  Budget  \
# 11   False               False    False     False         False   False
# 25   False               False    False     False         False   False
# 72   False               False    False     False         False   False
# 102  False               False    False     False         False   False
# 127  False               False    False     False         False   False
# 147  False               False    False     False         False   False
# 155  False               False    False     False         False   False
# 159  False               False    False     False         False   False
# 173  False               False    False     False         False   False
# 179  False               False    False     False         False   False
# 188  False               False    False     False         False   False
# 194  False               False    False     False         False   False
# ...

# %%
imdb.dtypes #datatypes of all columns
# Out:
# title                  object
# Production company     object
# Country                object
# Language               object
# Running time          float64
# Budget                float64
# Box office            float64
# Release date           object
# imdb                  float64
# metascore             float64
# rotten_tomatoes        object
# Directed by            object
# Produced by            object
# Based on               object
# Starring               object
# Music by               object
# Distributed by         object
# Cinematography         object
# Edited by              object
# Screenplay by          object
# dtype: object

# %%
imdb ["rotten_tomatoes"] = imdb.rotten_tomatoes.apply (lambda x: x.replace("%", " ")).astype("int64") #change datatype to  integer64

# %%
imdb.head() #top ten
# Out:
#                             title       Production company        Country  \
# 11              Song of the South  Walt Disney Productions  United States
# 25   20,000 Leagues Under the Sea  Walt Disney Productions  United States
# 72                   Mary Poppins  Walt Disney Productions  United States
# 102      Bedknobs and Broomsticks  Walt Disney Productions  United States
# 127                 Freaky Friday  Walt Disney Productions  United States
#
#     Language  Running time     Budget   Box office Release date  imdb  \
# 11   English          94.0  2125000.0   65000000.0   1946-11-12   7.1
# 25   English         127.0  5000000.0   28200000.0   1954-12-23   7.2
# 72   English         139.0        4.4  103100000.0   1964-08-27   7.8
# 102  English         118.0  6300000.0   17900000.0   1971-10-07   7.1
# 127  English          95.0  5000000.0   36000000.0   1976-12-20   6.2
#
#      metascore  rotten_tomatoes  \
# 11        54.0               50
# ...

# %%
imdb.rotten_tomatoes.dtype
# Out:
# dtype('int64')

# %%
 imdb.sort_values (by ="rotten_tomatoes", ascending = False )
# Out:
#                                                  title  \
# 72                                        Mary Poppins
# 290                                         Glory Road
# 409                                              Dumbo
# 298                     The Nightmare Before Christmas
# 353                                           Arrietty
# 396                               Beauty and the Beast
# 413                                      The Lion King
# 211                          James and the Giant Peach
# 375                                         Big Hero 6
# 25                        20,000 Leagues Under the Sea
# 127                                      Freaky Friday
# 265                                      Freaky Friday
# 359                                      Frankenweenie
# 226                                    The Parent Trap
# 429                                              Mulan
# 155                                                Tex
# ...

# %%
imdb[imdb.rotten_tomatoes== 100].count()
# Out:
# title                 0
# Production company    0
# Country               0
# Language              0
# Running time          0
# Budget                0
# Box office            0
# Release date          0
# imdb                  0
# metascore             0
# rotten_tomatoes       0
# Directed by           0
# Produced by           0
# Based on              0
# Starring              0
# Music by              0
# Distributed by        0
# Cinematography        0
# Edited by             0
# Screenplay by         0
# dtype: int64

# %%
Toptenrt = imdb.sort_values (by ="rotten_tomatoes", ascending = False ).head(10)

# %%
ToptenIMDB= imdb.sort_values(by= "imdb", ascending = False).head(10)

# %%
 ToptenIMDB #returns top ten movies according to imdb
# Out:
#                               title  \
# 413                   The Lion King
# 298  The Nightmare Before Christmas
# 396            Beauty and the Beast
# 72                     Mary Poppins
# 375                      Big Hero 6
# 429                           Mulan
# 353                        Arrietty
# 287   The Greatest Game Ever Played
# 292                     Eight Below
# 25     20,000 Leagues Under the Sea
#
#                                     Production company        Country  \
# 413  ['Walt Disney Pictures', 'Fairview Entertainme...  United States
# 298  ['Touchstone Pictures', 'Skellington Productio...  United States
# 396       ['Walt Disney Pictures', 'Mandeville Films']  United States
# 72                             Walt Disney Productions  United States
# 375  ['Walt Disney Pictures', 'Walt Disney Animatio...  United States
# 429  ['Walt Disney Pictures', 'Jason T. Reed Produc...  United States
# ...

# %%
#This is a simple data analysis of the given dataset of disney movies, we can use this dataset to do a plathera of other things
#like draw graphs (using python's matplotlib) and pie charts, etc however the purpose of this project was just to use datamining
#to see what techniques can be adequately deployed to extract desired data from the dataset gven. 201722150010.
